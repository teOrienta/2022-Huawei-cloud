# %%
import pandas as pd

licitacoes_file_path = "./data/202101_Licitacoes/202101_Licitacao.csv"

# %%
date_columns = ["Data Abertura"]

df = pd.read_csv(licitacoes_file_path, sep=';', parse_dates=date_columns, encoding='ISO 8859-1')

df.head()
# Out:
#    Número Licitação  Código UG                                        Nome UG  \
# 0             12019     154628        INST.FEDERAL FARROUPILHA CAMPUS JAGUARI
# 1             12020     114616            UNIDADE ESTADUAL DO IBGE EM SERGIPE
# 2             12020     154699           INST. FED. DO PARANA/CAMPUS LONDRINA
# 3             12020     158357               INST. FED. PIAUI/CAMPUS PARNAIBA
# 4             12020     158429  INST.FED. ESPIRITO SANTO/CAMPUS V.N. DO IMIGR
#
#    Código Modalidade Compra           Modalidade Compra    Número Processo  \
# 0                         2            Tomada de Preços  26420000767201908
# 1                         5                      Pregão  021125.70/2020-51
# 2                       -99  Pregão - Registro de Preço  23411011872202019
# 3                       -99  Pregão - Registro de Preço  23179000200202088
# 4                       -99  Pregão - Registro de Preço  23186001885201932
#
# ...

# %%
df['Número Licitação'].value_counts()
# Out:
# 12021        635
# 22021        303
# 32021        174
# 42021        126
# 52021         88
#             ...
# 2732019        1
# 2702020        1
# 2692020        1
# 2682020        1
# 731372020      1
# Name: Número Licitação, Length: 539, dtype: int64

# %%
df['Número Processo'].value_counts()
# Out:
# 64033007749202035    31
# 63069001806201373    20
# 0058800185202012     19
# 63037002719201815     7
# 23078533323201814     6
#                      ..
# 014/IMBEL/FPV/21      1
# 2021IN000003          1
# 2020DL00000003-FE     1
# 19615720003202104     1
# 73137/2020            1
# Name: Número Processo, Length: 3081, dtype: int64

# %%
df['Situação Licitação'].value_counts()
# Out:
# Encerrado                         1228
# Publicado                         1175
# Evento de Resultado de Julgame     525
# Divulgado                           73
# Evento de Alteração Publicado       52
# Evento de Suspensão Publicado       41
# Retificação                         30
# Evento de Revogação Publicado       25
# Evento de Retificação Publicad      22
# Anulação                            20
# Revogação                           16
# Evento de Alteração de Resulta      16
# Evento de Adiamento Publicado       13
# Evento de Adiamento Divulgado        9
# Evento de Anulação Publicado         8
# Evento de Alteração Divulgado        7
# Inválido                             4
# Evento de Reabertura de Prazo        3
# Evento de Retificação Divulgad       3
# Name: Situação Licitação, dtype: int64

# %%
filtered_df = df[df['Número Licitação'] == 52021]
filtered_df.head(50)
# Out:
#       Número Licitação  Código UG  \
# 1397             52021     110097
# 1398             52021     114610
# 1399             52021     114702
# 1400             52021     130063
# 1401             52021     130074
# 1402             52021     130075
# 1403             52021     133080
# 1404             52021     135024
# 1405             52021     153046
# 1406             52021     153052
# 1407             52021     153056
# 1408             52021     153063
# 1409             52021     153079
# 1410             52021     153114
# 1411             52021     153114
# 1412             52021     153115
# 1413             52021     153149
# 1414             52021     153155
# 1415             52021     153164
# 1416             52021     153254
# 1417             52021     154003
# 1418             52021     154042
# 1419             52021     154502
# 1420             52021     155008
# 1421             52021     155010
# 1422             52021     155019
# ...
